# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
import pandas as pd
states = list(pd.read_csv('data/us-states-only.csv').state)

# %%
state = widgets.Select(
    options=states,
    value='Alabama',
    # rows=10,
    description='State:',
    disabled=False
    )

# %%
from datetime import datetime
date = widgets.DatePicker(description='Date',
                          value=datetime.today(),
                          disabled=False
                          )

# %%
from datetime import datetime
def show_data(st, dt):
    dt = datetime.strftime(dt, '%m-%d-%Y')
    df = pd.read_csv('data/us-states-only.csv')
    print(df[df.state==st])

# %%
widgets.interactive(show_data, st=state, dt=date)
# Out:
# interactive(children=(Select(description='State:', index=40, options=('Alabama', 'Alaska', 'Arizona', 'Arkansa…
